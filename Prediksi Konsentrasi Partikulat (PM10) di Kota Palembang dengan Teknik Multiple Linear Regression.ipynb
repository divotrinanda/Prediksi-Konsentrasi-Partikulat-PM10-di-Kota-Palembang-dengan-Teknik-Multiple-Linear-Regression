# %%
import numpy as np
import pandas as pd

# %%
cd
# Out:
# C:\Users\divot

# %%
pwd
# Out:
# 'C:\\Users\\divot'

# %%
df = pd.read_excel('2015rev.xlsx')

# %%
df
# Out:
#         Tanggal  Jam      Lokasi    PM10   RH   TEMP
# 0    2015-01-01    0  PALEMBANG    28.91  100  23.63
# 1    2015-01-01    1  PALEMBANG    52.00  100  23.62
# 2    2015-01-01    2  PALEMBANG    64.97  100  23.42
# 3    2015-01-01    3  PALEMBANG    32.78  100  22.97
# 4    2015-01-01    4  PALEMBANG    12.44  100  22.72
# 5    2015-01-01    5  PALEMBANG     1.35  100  22.58
# 6    2015-01-01    6  PALEMBANG     0.88  100  23.03
# 7    2015-01-01    7  PALEMBANG    11.84  100  23.88
# 8    2015-01-01    8  PALEMBANG    53.09   95  26.02
# 9    2015-01-01    9  PALEMBANG   131.46   77  28.86
# 10   2015-01-01   10  PALEMBANG   214.94   72  30.02
# 11   2015-01-01   11  PALEMBANG   207.78   72  29.89
# 12   2015-01-01   12  PALEMBANG   147.68   68  31.00
# 13   2015-01-01   13  PALEMBANG   105.62   70  30.52
# 14   2015-01-01   14  PALEMBANG    57.13   71  30.37
# 15   2015-01-01   15  PALEMBANG    35.00   72  29.89
# 16   2015-01-01   16  PALEMBANG    17.70   82  28.49
# ...

# %%
x=df.PM10

# %%
x
# Out:
# 0        28.91
# 1        52.00
# 2        64.97
# 3        32.78
# 4        12.44
# 5         1.35
# 6         0.88
# 7        11.84
# 8        53.09
# 9       131.46
# 10      214.94
# 11      207.78
# 12      147.68
# 13      105.62
# 14       57.13
# 15       35.00
# 16       17.70
# 17        1.28
# 18       18.10
# 19       25.29
# 20       48.21
# 21      112.43
# 22      179.98
# 23      205.01
# 24      169.43
# 25      123.82
# 26      116.43
# 27      135.12
# 28      107.15
# 29       46.58
#          ...
# 6015     55.28
# 6016     25.72
# 6017     33.35
# 6018     42.81
# 6019     35.18
# 6020     10.57
# 6021      5.90
# 6022     16.43
# 6023     21.93
# 6024     21.42
# 6025     10.52
# 6026      4.83
# 6027      3.67
# 6028     14.18
# 6029     15.60
# 6030     20.66
# 6031     66.93
# 6032     97.12
# 6033     91.97
# 6034     80.07
# 6035     59.65
# 6036     38.11
# 6037     34.91
# 6038     26.74
# 6039      1.09
# 6040      3.35
# 6041      6.88
# ...

# %% [raw]
# MEAN

# %%
np.mean(x)
# Out:
# 128.28925062034747

# %%
xWithNan = np.hstack( (x, np.nan) ) # append nan

# %%
np.mean(xWithNan)
# Out:
# nan

# %%
np.nanmean(xWithNan)
# Out:
# 128.2892506203474

# %% [raw]
# MEDIAN

# %%
np.median(x)
# Out:
# 82.97

# %% [raw]
# MODE

# %%
from scipy import stats

# %%
stats.mode(x)
# Out:
# ModeResult(mode=array([0.]), count=array([16]))

# %% [raw]
# GEOMETRIC MEAN

# %%
A = np.arange(1,101)

# %%
stats.gmean(A)
# Out:
# 37.992689344834304

# %% [raw]
# Quantifying Variability

# %%
range = np.ptp(x)

# %%
data = np.arange(7,14)

# %%
np.std(data, ddof=0)
# Out:
# 2.0

# %%
np.std(data, ddof=1)
# Out:
# 2.160246899469287
